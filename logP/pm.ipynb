# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = os.getcwd()
dirname = os.path.dirname(path)

# %%
#mse
SMALL_SIZE = 8
MEDIUM_SIZE = 16
BIGGER_SIZE = 30

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE) 
N = 4

# Specify the values of first bars (height)
first_bar = (0.511, 0.335, 0.248, 0.621)

# Specify the values of second bars (height)
second_bar = (0.439, 0.280, 0.262, 0.586)

# Position of bars on x-axis
ind = np.arange(N)

# Position of bars on x-axis
ind = np.arange(N)

# Width of a bar
width = 0.3

# %%
#plotting
plt.bar(ind,first_bar ,width, label = 'Without LC informations',hatch='/////',edgecolor='black',color='white')#yerr=[0.061,0.056,0.058,0.080],capsize=6,ecolor='black')
plt.bar(ind + width, second_bar, width, label = 'With LC informations',edgecolor='black',color='black')#yerr= [0.057,0.057,0.059,0.074],capsize=6,ecolor='black')
plt.ylabel('Mean Squared Error')
plt.xticks(ind+width/2,('SVM','XGB','MLP','RF'))
plt.savefig(dirname+"p_chem/results/mse.png", format='png', dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/hj/4_1_bgn11_dgm99bq0lnjxl80000gn/T/ipykernel_8892/2620936233.py in <module>
#       4 plt.ylabel('Mean Squared Error')
#       5 plt.xticks(ind+width/2,('SVM','XGB','MLP','RF'))
# ----> 6 plt.savefig(dirname+"p_chem/results/mse.png", format='png', dpi=600)
#       7 plt.show()
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3017                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3018
# -> 3019             self.canvas.print_figure(fname, **kwargs)
#    3020
#    3021     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     539         """
#     540         FigureCanvasAgg.draw(self)
# --> 541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# ~/miniforge3/envs/ds/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2207                 fp = builtins.open(filename, "r+b")
#    2208             else:
# -> 2209                 fp = builtins.open(filename, "w+b")
#    2210
#    2211         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/p_chem/results/mse.png'

# %%
#rmse

# Data on X-axis

# Specify the values of first bars (height)
first_bar = (0.741, 0.582, 0.516, 0.789 )

# Specify the values of second bars (height)
second_bar = (0.717, 0.556, 0.509, 0.764)

# Position of bars on x-axis
ind = np.arange(N)

# Width of a bar
width = 0.3

#plotting
plt.bar(ind,first_bar ,width, label = 'Without LC informations',hatch='/////',edgecolor='black',color='white')#,yerr=[0.058,0.045,0.056,0.051],capsize=6,ecolor='black')
plt.bar(ind + width, second_bar, width, label = 'With LC informations',edgecolor='black',color='black')#,yerr= [0.056,0.047,0.056,0.050],capsize=6,ecolor='black')
plt.ylabel('Root Mean Squared Error')
plt.xticks(ind+width/2,('SVM','XGB','MLP','RF'))
# plt.ylim(0.40,0.90)
#plt.savefig("rmse.png", format='png', dpi=600)
plt.show()

# %%
 #mae

# Data on X-axis

# Specify the values of first bars (height)
first_bar = (0.544, 0.414, 0.372, 0.586)

# Specify the values of second bars (height)
second_bar = (0.489,0.394, 0.367, 0.574)

# Position of bars on x-axis
ind = np.arange(N)

# Width of a bar
width = 0.3

#plotting
plt.bar(ind,first_bar ,width, label = 'Without LC informations',hatch='/////',edgecolor='black',color='white')
            #yerr=[0.024,0.024,0.025,0.033],capsize=6,ecolor='black')
plt.bar(ind + width, second_bar, width, label = 'With LC informations',edgecolor='black',color='black')
            #yerr= [0.022,0.025,0.029,0.031],capsize=6,ecolor='black')
plt.ylabel('Mean Absolute Error')
plt.xticks(ind+width/2,('SVM','XGB','MLP','RF'))
#plt.savefig("mae.png", format='png', dpi=600)
plt.show()

# %%
# r2

# Data on X-axis

# Specify the values of first bars (height)
first_bar = (0.836, 0.850, 0.881, 0.727)

# Specify the values of second bars (height)
second_bar = (0.849, 0.862, 0.884, 0.742)

# Position of bars on x-axis
ind = np.arange(N)

# Width of a bar
width = 0.3

#plotting
plt.bar(ind,first_bar ,width, label = 'Without LC informations',hatch='/////',edgecolor='black',color='white')
            #yerr=[0.031,0.029,0.030,0.038],capsize=6,ecolor='black')
plt.bar(ind + width, second_bar, width, label = 'With LC informations',edgecolor='black',color='black')
            #yerr= [0.029,0.031,0.030,0.036],capsize=6,ecolor='black')
plt.ylabel('Coefficient of determination(R2)')
plt.xticks(ind+width/2,('SVM','XGB','MLP','RF'))
plt.ylim(0.680,0.94)
#plt.savefig("r2.png", format='png', dpi=600)
plt.show()
